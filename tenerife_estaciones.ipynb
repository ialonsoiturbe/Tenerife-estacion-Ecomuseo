# %% [markdown]
# # Datos meteorológicos de Tenerefife de la estación Ecomuseo

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

#Ignoro los warnings para que quede + bonito pero no se debe abusar de esto
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Vamos a analizar los datos meteorológicos del 2026 de Tenerife recogidos en las estaciones metereológicas que nos proporcionan desde el Cabildo Insular de Tenerife:
#
# https://datos.gob.es/es/catalogo/conjuntos-datos?publisher_display_name=Cabildo+Insular+de+Tenerife
#
# Primero recogeremos los datos en csv de todas las estaciones y las exploraremos sin manipularlas para conocer qué datos hemos recogido.
# ![Mapa estaciones de Tenerife](mapa_tenerife_estaciones.png)

# %%
#Leemos los 67 dataset 
df_ecomuseo = pd.read_csv('https://datos.tenerife.es/ckan/dataset/f9564dce-9106-4747-9758-51bed4f12afa/resource/99a5dd1d-b72b-4e1c-a1da-6698fb4b8dcc/download/datos-meteorologicos-diarios-ecomuseo-2026.csv')
df_tenoalto = pd.read_csv('https://datos.tenerife.es/ckan/dataset/c39a5ac7-534a-411f-bb0b-b6415d58237f/resource/f885353d-3bb3-42ba-b527-5cb190ef837a/download/datos-meteorologicos-diarios-teno_alto-2026.csv')
df_correderas = pd.read_csv('https://datos.tenerife.es/ckan/dataset/1e0029f3-ebb0-4f1f-9fbc-737676ddf9f8/resource/1945416d-0eba-4086-b32c-389f8780b9ad/download/datos-meteorologicos-diarios-montana_correderas-2026.csv')
df_sietefuentes = pd.read_csv('https://datos.tenerife.es/ckan/dataset/597a776d-c4fa-45f3-b604-d6da7b5bdc6d/resource/ef91f479-ed18-41aa-94df-258a5ce72743/download/datos-meteorologicos-diarios-siete_fuentes-2026.csv')
df_llanadas = pd.read_csv('https://datos.tenerife.es/ckan/dataset/d44cc9fe-af7e-41ac-9f4d-41dd3c83c18f/resource/c9474661-5a95-4e04-a15e-211ede796791/download/datos-meteorologicos-diarios-llanadas-2026.csv')
df_vilaflorforestal = pd.read_csv('https://datos.tenerife.es/ckan/dataset/21298cab-f6aa-4f80-812a-e369360fdbde/resource/a8e1a27e-53e3-41fc-b000-b3c7fa5499e5/download/datos-meteorologicos-diarios-vilaflor_forestal-2026.csv')
df_tacorth = pd.read_csv('https://datos.tenerife.es/ckan/dataset/591389fd-c66b-4dcb-9f38-e9186508e994/resource/3ce41893-a411-4e82-ab98-dc84b363065c/download/datos-meteorologicos-diarios-tacorth-2026.csv')
df_araya = pd.read_csv('https://datos.tenerife.es/ckan/dataset/db1eee35-d3b5-474d-b095-d65dfb476c79/resource/a05a33c0-93ef-4f4d-9122-f4bc9300612a/download/datos-meteorologicos-diarios-araya-2026.csv')
df_llanitop = pd.read_csv('https://datos.tenerife.es/ckan/dataset/5a1d90e0-cc1c-49aa-8a97-bcb1e6996216/resource/db289885-1b25-43c7-afe9-9ef410cbc240/download/datos-meteorologicos-diarios-llanitop-2026.csv')
df_mazape = pd.read_csv('https://datos.tenerife.es/ckan/dataset/2fa0b8f5-aabf-499f-b7a5-8be2a7e0ad88/resource/58a98d3d-e5a8-4720-a79a-1029459ce73b/download/datos-meteorologicos-diarios-imetos_mazape-2026.csv')
df_ravelo = pd.read_csv('https://datos.tenerife.es/ckan/dataset/7063b00e-7003-4eb6-948b-1f2a721e870e/resource/9b2c7a1e-ec2e-425b-a930-9646ee3628bb/download/datos-meteorologicos-diarios-imetos_ravelo-2026.csv')
df_tacoronte = pd.read_csv('https://datos.tenerife.es/ckan/dataset/c289f321-bee6-4a40-b909-1945653b8eaf/resource/f1563ff1-27f5-446b-a528-090632e8b5c9/download/datos-meteorologicos-diarios-imetos_tacoronte-2026.csv')
df_benijth = pd.read_csv('https://datos.tenerife.es/ckan/dataset
= pd.read_csv('https://datos.tenerife.es/ckan/dataset/2c301677-996d-4933-ac93-50b8a1f4e245/resource/a3a041f4-e8f3-4c99-a131-1b109028393e/download/datos-meteorologicos-diarios-badajth-2026.csv')
df_laguna = pd.read_csv('https://datos.tenerife.es/ckan/dataset/23ae1037-c825-40b7-85ce-237e8c013f10/resource/03f428cb-c6ef-4223-9d20-8c918e568cb6/download/datos-meteorologicos-diarios-laguna-2026.csv')
df_tejina01 = pd.read_csv('https://datos.tenerife.es/ckan/dataset/c4c90974-d1ba-47c7-8159-18a0a266b4f1/resource/557def74-3fbe-41a8-a1bc-b0cc62aa3542/download/datos-meteorologicos-diarios-tejina01-2026.csv')
df_realeth = pd.read_csv('https://datos.tenerife.es/ckan/dataset/c4a896e9-bec2-4fef-acd6-5d9f52274d4f/resource/9dabbad0-f618-4a19-bda5-32debb7ad783/download/datos-meteorologicos-diarios-realeth_n-2026.csv')
df_orotav01 = pd.read_csv('https://datos.tenerife.es/ckan/dataset/d7f76055-5199-406a-8e2f-317b4c0a3044/resource/9759483d-c06d-4991-b6b9-6cac26fb2faa/download/datos-meteorologicos-diarios-orotav01-2026.csv')
df_alcala = pd.read_csv('https://datos.tenerife.es/ckan/dataset/4b14512a-a5f8-423b-b821-5855395eaeb5/resource/f24dc285-e6a4-43c0-8b02-022b75f36870/download/datos-meteorologicos-diarios-alcala-2026.csv')
df_hoyagrande = pd.read_csv('https://datos.tenerife.es/ckan/dataset/41ddcb9e-c00e-4eb7-a83f-0d93dd6b2134/resource/3bcf63e9-513a-4123-9dec-a728e12e2b79/download/datos-meteorologicos-diarios-hoya_grande-2026.csv')
df_gaitero = pd.read_csv('https://datos.tenerife.es/ckan/dataset/d80f40b5-14de-45e7-8243-577bb9f42de8/resource/0e655e8a-b8b4-445b-abf8-9b7dc32c650c/download/datos-meteorologicos-diarios-gaitero_ma-2026.csv')
df_chavao = pd.read_csv('https://datos.tenerife.es/ckan/dataset/9fb089b1-beb8-4221-b01a-446830c88c7d/resource/410b75b1-184e-42d1-b3b8-c792ac6e0fff/download/datos-meteorologicos-diarios-chavao_ma-2026.csv')
df_picacho = pd.read_csv('https://datos.tenerife.es/ckan/dataset/56da6c5b-c118-4f68-b2b3-070b0ff88176/resource/a3e3a6f8-f0fc-4ea7-90bc-3b09c6170367/download/datos-meteorologicos-diarios-picacho_ma-2026.csv')
df_santacruz = pd.read_csv('https://datos.tenerife.es/ckan/dataset/ef37ec79-7bf3-45a4-b617-00afa8ba219d/resource/bcc16653-b716-4d5a-a2ed-08cdd722500d/download/datos-meteorologicos-diarios-santa_cruz-2026.csv')
df_taganana = pd.read_csv('https://datos.tenerife.es/ckan/dataset/cbd4fc92-e465-4b2a-a47b-d271dda7941d/resource/d1d2d1f9-5147-4f0c-89f2-66c40e8a27e3/download/datos-meteorologicos-diarios-taganana-2026.csv')
df_bailadero = pd.read_csv('https://datos.tenerife.es/ckan/dataset/b07c2ed8-4dc0-44df-9d45-8c236dbb222c/resource/8564dadb-4db6-4950-a59f-516eff55d8a7/download/datos-meteorologicos-diarios-bailadero-2026.csv')
df_ravelo01 = pd.read_csv('https://datos.tenerife.es/ckan/dataset/dd170327-a63c-480c-8c1d-1d56e7c40d97/resource/41fcda29-ee18-435a-b192-8b5d5630b93b/download/datos-meteorologicos-diarios-ravelo01-2026.csv')
df_galletas = pd.read_csv('https://datos.tenerife.es/ckan/dataset/bc4d2d48-d710-4637-b139-a21453e2cd47/resource/e673cd8d-1f3e-429e-8fb5-ef5bc9777aab/download/datos-meteorologicos-diarios-galletas-2026.csv')

df_galletas.info()

#Dimensiones del dataset
print("Filas:", df_galletas.shape[0])
print("Columnas:", df_galletas.shape[1])

#Ver el dataset
df_galletas.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4024 entries, 0 to 4023
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   estacion_id        4024 non-null   int64
#  1   estacion_nombre    4024 non-null   object
#  2   sensor_id          4024 non-null   int64
#  3   sensor_alias       4024 non-null   object
#  4   sensor_nombre      4024 non-null   object
#  5   fecha_observacion  4024 non-null   object
#  6   metrica            4024 non-null   object
#  7   valor              2728 non-null   float64
# dtypes: float64(1), int64(2), object(5)
# memory usage: 251.6+ KB
# Filas: 4024
# Columnas: 8
#    estacion_id estacion_nombre  sensor_id sensor_alias         sensor_nombre  \
# 0            2        GALLETAS        350          WSP  Velocidad del viento
# 1            2        GALLETAS        350          WSP  Velocidad del viento
# ...

# %% [markdown]
# Vemos que sigue la misma estructura que ya vimos con la estación Ecomuseo por lo que tampoco nos interesa demasiado ver los missing de cada dataset ya que será parecido. Vamos a ir directamente a cambiar el formato de la fecha de objeto a datetime.

# %%
lista_estaciones = [
    df_ecomuseo, df_correderas, df_sietefuentes, df_llanadas, df_vilaflorforestal, df_tacorth, df_araya, df_llanitop, df_mazape, df_ravelo, df_tacoronte, df_benijth, df_toponegr,
    df_trigoth, df_drago, df_igueste, df_pozoth, df_guiath, df_eres, df_elviento, df_redonth, df_abonacop, df_chioth, df_topoma, df_matanth, df_silos, df_ursumedi, df_vilaflor,
    df_pinalth, df_pabloth, df_victoth, df_trevejos, df_menath, df_tegueste, df_elrosario, df_suerteth, df_anavisth, df_hoyosth, df_helecho1, df_smigth, df_ursubaja, df_ursulath,
    df_icor, df_arico01, df_laquinta, df_guiasi01, df_aguamansama, df_bvista02, df_palmath, df_guan1ha1, df_galecubo, df_ratino01, df_badajth, df_laguna, df_tejina01, df_realeth,
    df_orotav01, df_alcala, df_hoyagrande, df_gaitero, df_chavao, df_picacho, df_santacruz, df_taganana, df_bailadero, df_ravelo01, df_galletas, df_tenoalto]

for i in range(len(lista_estaciones)):
    lista_estaciones[i]['fecha_observacion'] = pd.to_datetime(lista_estaciones[i]['fecha_observacion'])
  
#Revisemos una para comprobar si ha hecho el cambio
df_alcala.dtypes
# Out:
# estacion_id                   int64
# estacion_nombre              object
# sensor_id                     int64
# sensor_alias                 object
# sensor_nombre                object
# fecha_observacion    datetime64[ns]
# metrica                      object
# valor                       float64
# dtype: object

# %% [markdown]
# # Los diferentes sensores son:
#
# WSP - Velocidad del viento
#
# TEMP - Temperatura
#
# HUM - Humedad relativa
#
# RAIN - Precipitaciones
#
# RAD - Radiación solar
#
#
# Para hacer un análisis de los datos vamos a visualizar las medidas por fecha. Para ello primero vamos a dividir el df para cada sensor y comparar estos datos en un gráfico. Dividimos el dataset en varios subdataset porque si no no podemos realmente ver el valor de cada uno distinto y se pueden mezclar datos, separar los dataset nos permite analizar de forma clara y diferenciada cada tipo de medida.

# %%
#Funcion para comparar los datos de cada sensor por estacion
def crear_comparacion(lista_estaciones, sensor):
    #Nos quedamos con la metrica que más nos interesa de cada sensor
    metricas_sensor = {
        "TEMP": "media",
        "HUM": "media",
        "WSP": "media",
        "RAIN": "total",
        "RAD": "total"      # o "maximo" si prefieres comparar el pico diario
    }

    metrica = metricas_sensor[sensor]

    series = []
    
    #dividimos por estaciones para que nos grafique todas de golpe
    for df in lista_estaciones:

        nombre = df["estacion_nombre"].iat[0]

        tabla = (
            df[df["sensor_alias"] == sensor]
            .pivot_table(
                index="fecha_observacion",
                columns="metrica",
                values="valor",
                aggfunc="first"
            )
        )

        if metrica in tabla.columns:
            series.append(tabla[metrica].rename(nombre))

    return pd.concat(series, axis=1)

#Agrupamos los sensores
temp = crear_comparacion(lista_estaciones, "TEMP")
hum  = crear_comparacion(lista_estaciones, "HUM")
wsp  = crear_comparacion(lista_estaciones, "WSP")
rain = crear_comparacion(lista_estaciones, "RAIN")
rad  = crear_comparacion(lista_estaciones, "RAD")

# %% [markdown]
# # SENSORES
# Ahora que tenemos todos los datos separados por sensor y por estación, vamos a representarlos y enfrentarlos por los valores de las métricas.

# %%
for nombre, df in {
    "Temperatura": temp,
    "Humedad": hum,
    "Viento": wsp,
    "Lluvia": rain,
    "Radiación": rad
}.items():

    plt.figure(figsize=(14,6))

    for estacion in df.columns:
        plt.plot(df.index, df[estacion], label=estacion)

    plt.title(nombre)
    plt.xlabel("Fecha")
    plt.ylabel(nombre)
    plt.grid(True)

    # Si tienes muchas estaciones
    plt.legend(bbox_to_anchor=(1.02, 1), loc="upper left", fontsize=8)

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Estaciones
#
# Como podemos observar es muy difícil de leer estas gráficas por la cantidad de estaciones representadas al mismo tiempo. Recurriendo al mapa inicial vamos a elegir, para cada tipo de sensor, uno en cada zona para ver la variación de sus datos meteorológicos según su localización.
#
# __Tipo I__: Silos(SILOS), La Laguna(TEJINA01), Güimar(EL VIENTO), Galletas(ARONA).
#
# __Tipo II__: Guía de Isora( GUIA), Los Realejos(REALE), Santa Cruz de Tenerife(BAILADERO), Fasnia(ERES).
#
# __Tipo III__: Buena Vista del Norte(Teno_Alto), La Victoria(GAITERO), Guía de Isora(CHAVAO), Arico(PICACHO).
#
# __Tipo IV__: El Tanque(ECOMUSEO), Santiago del Teide(MONTAÑA CORREDERAS), Villaflor(VILLAFLOR_FORESTAL), Arico(Siete Fuente).

# %%
#Haremos la misma lógica pero en vez de todas las estaciones, una lista para cada tipo de estación, para poder comparar entre ellas.
#Tipo I
tipo_1 = [df_elviento, df_silos, df_tejina01, df_galletas]

for i in range(len(tipo_1)):
    tipo_1[i]['fecha_observacion'] = pd.to_datetime(tipo_1[i]['fecha_observacion'])

#Tipo II
tipo_2 = [df_eres, df_guiath, df_santacruz,  df_bailadero,]

for i in range(len(tipo_2)):
    tipo_2[i]['fecha_observacion'] = pd.to_datetime(tipo_2[i]['fecha_observacion'])

#Tipo III
tipo_3 = [df_tenoalto, df_gaitero, df_chavao, df_picacho]

for i in range(len(tipo_3)):
    tipo_3[i]['fecha_observacion'] = pd.to_datetime(tipo_3[i]['fecha_observacion'])

#Tipo IV
tipo_4 = [df_ecomuseo, df_correderas, df_sietefuentes, df_vilaflorforestal]

for i in range(len(tipo_4)):
    tipo_4[i]['fecha_observacion'] = pd.to_datetime(tipo_4[i]['fecha_observacion'])
  
#Revisemos una para comprobar si ha hecho el cambio
df_elviento.dtypes
# Out:
# estacion_id                   int64
# estacion_nombre              object
# sensor_id                     int64
# sensor_alias                 object
# sensor_nombre                object
# fecha_observacion    datetime64[ns]
# metrica                      object
# valor                       float64
# dtype: object

# %%
#Vamos a agrupar los sensores por cadatipo de estación y graficar para poder comparar entre ellas.
#Agrupamos los sensores para el Tipo I
temp1 = crear_comparacion(tipo_1, "TEMP")
hum1  = crear_comparacion(tipo_1, "HUM")
wsp1  = crear_comparacion(tipo_1, "WSP")
rain1 = crear_comparacion(tipo_1, "RAIN")
rad1  = crear_comparacion(tipo_1, "RAD")

#Agrupamos los sensores para el Tipo II
temp2 = crear_comparacion(tipo_2, "TEMP")
hum2  = crear_comparacion(tipo_2, "HUM")
wsp2  = crear_comparacion(tipo_2, "WSP")
rain2 = crear_comparacion(tipo_2, "RAIN")
rad2  = crear_comparacion(tipo_2, "RAD")

#Agrupamos los sensores para el Tipo III
temp3 = crear_comparacion(tipo_3, "TEMP")
hum3  = crear_comparacion(tipo_3, "HUM")
wsp3  = crear_comparacion(tipo_3, "WSP")
rain3 = crear_comparacion(tipo_3, "RAIN")
rad3  = crear_comparacion(tipo_3, "RAD")

#Agrupamos los sensores para el Tipo IV
temp4 = crear_comparacion(tipo_4, "TEMP")
hum4  = crear_comparacion(tipo_4, "HUM")
wsp4  = crear_comparacion(tipo_4, "WSP")
rain4 = crear_comparacion(tipo_4, "RAIN")
rad4  = crear_comparacion(tipo_4, "RAD")

# %% [markdown]
# # Tipo I:
# Empezamos con la visualización de los sensores tipo I.

# %%
#Graficamos las de tipo I
for nombre, df in {
    "Temperatura": temp1,
    "Humedad": hum1,
    "Viento": wsp1,
    "Lluvia": rain1,
    "Radiación": rad1
}.items():

    plt.figure(figsize=(14,6))

    for estacion in df.columns:
        plt.plot(df.index, df[estacion], label=estacion)

    plt.title(nombre)
    plt.xlabel("Fecha")
    plt.ylabel(nombre)
    plt.grid(True)

    # Si tienes muchas estaciones
    plt.legend(bbox_to_anchor=(1.02, 1), loc="upper left", fontsize=8)

    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Tipo II:
# Empezamos con la visualización de los sensores tipo II.

# %%
#Graficamos las de tipo II
for nombre, df in {
    "Temperatura": temp2,
    "Humedad": hum2,
    "Viento": wsp2,
    "Lluvia": rain2,
    "Radiación": rad2
}.items():

    plt.figure(figsize=(14,6))

    for estacion in df.columns:
        plt.plot(df.index, df[estacion], label=estacion)

    plt.title(nombre)
    plt.xlabel("Fecha")
    plt.ylabel(nombre)
    plt.grid(True)

    # Si tienes muchas estaciones
    plt.legend(bbox_to_anchor=(1.02, 1), loc="upper left", fontsize=8)

    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Tipo III:
# Empezamos con la visualización de los sensores tipo III.

# %%
#Graficamos las de tipo III
for nombre, df in {
    "Temperatura": temp3,
    "Humedad": hum3,
    "Viento": wsp3,
    "Lluvia": rain3,
    "Radiación": rad3
}.items():

    plt.figure(figsize=(14,6))

    for estacion in df.columns:
        plt.plot(df.index, df[estacion], label=estacion)

    plt.title(nombre)
    plt.xlabel("Fecha")
    plt.ylabel(nombre)
    plt.grid(True)

    # Si tienes muchas estaciones
    plt.legend(bbox_to_anchor=(1.02, 1), loc="upper left", fontsize=8)

    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Tipo IV:
# Empezamos con la visualización de los sensores tipo IV

# %%
#Graficamos las de tipo IV
for nombre, df in {
    "Temperatura": temp4,
    "Humedad": hum4,
    "Viento": wsp4,
    "Lluvia": rain4,
    "Radiación": rad4
}.items():

    plt.figure(figsize=(14,6))

    for estacion in df.columns:
        plt.plot(df.index, df[estacion], label=estacion)

    plt.title(nombre)
    plt.xlabel("Fecha")
    plt.ylabel(nombre)
    plt.grid(True)

    # Si tienes muchas estaciones
    plt.legend(bbox_to_anchor=(1.02, 1), loc="upper left", fontsize=8)

    plt.tight_layout()
    plt.show()
